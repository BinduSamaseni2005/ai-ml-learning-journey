# %% [markdown]
# # Flow controls
# ## conditionals
# ## loops

# %% [markdown]
# # Loops
# ### loop is a efficient way to tell a computer to perform command multiple times
# ### each iteration of the loop can perform the new data to perform the command or depend upon the previous loop
# ## there are 2 main types of the loops mainly : for, while

# %% [markdown]
# ## the for loop we tell python before doing anything how many time we are going through a loop , and what the index counter is on each of those times
# ### so first we need to tell it what a variable is in index location and then say what values is that index is going to take on
# #### variable stores the index location at each iteartion of the loop and it goes and then does the stuff inside the loop over and over again util it runs out the things to do

# %% [markdown]
# ### while loop check the condition and if condition is satisfied it does the internal part of thee loop and gets back and check the condition over and over again until the condition is not satisfied and then loop will end

# %%
# for loops
# there are a few ways to go through a for loop
# one common method is to loop through a list
# it is also possible to loop through other types of aggregated variables
# but one rule remains the same
# the insides of a loop are determined by tabs!!!!!!!!
# this is also true for conditionals and user defined functions!!!!!!

counter = 0
list = [0,1,2,3,4,5,6,2143,123,7834]
for i in list:
    # the only lines that get executed in this loop are tabbed correctly!!!
    print(i)
    counter = counter + 1
print('this line is not inside the loop')
print('the loop cycled',counter,'times')
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 2143
# 123
# 7834
# this line is not inside the loop
# the loop cycled 10 times

# %%
for i in list[1:4]:
    for j in list[4:7]:
        print(i*j)
    print('outside of j loop')
print('outiside of the both loops')
# Out:
# 4
# 5
# 6
# outside of j loop
# 8
# 10
# 12
# outside of j loop
# 12
# 15
# 18
# outside of j loop
# outiside of the both loops

# %%
# we may want to loop over a range of values
# for that we will use range
print(range(6))
# Out:
# range(0, 6)

# %%
for i in range(6):
    print(i)
#if we keep large number like 7000000 something it requires a lot of memory space
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# we can specify the range values
# left values is inclusive and right value is exclusive
for i in range(4,10):
    print(i)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#increment by specific amount
for i in range(2,10,2):
    print(i)
    #here 3 value in the range is how much to increment by
# Out:
# 2
# 4
# 6
# 8

# %%
#we can convert range to list
list(range(6,15,3))
# Out:
# [6, 9, 12]

# %% [markdown]
# # while loops

# %%
#inside of the while loop is still determined by the tabs
i =4
while i<10:
    print(i)
    i = i+1
print('outside the loop')
# Out:
# 4
# 5
# 6
# 7
# 8
# 9
# outside the loop

# %% [markdown]
# # conditionals
# ## there 3 types of conditional statements
# 1. if
# 2. else
# 3. elif

# %%
i = 3
if i<10: 
    print(i, 'is less than 10')
    print('run this also')
else:
    print(i,'is greater than or equal to 10')
# Out:
# 3 is less than 10
# run this also

# %%
i =8
if i>10:
    print(i,'is greater than 10')
elif i<3:
    print(i,'is less then 3')
else:
    print(i,'is between 3 and 10')
# Out:
# 8 is between 3 and 10

# %% [markdown]
# # user defined functions
# ## useful define our own function to do something and ask python to call that function
# ### this is useful when we want to perform same computation in different scenarios . if we put this computation inside function then no eed to rewrite function again and again each time we want to make the computation
# ## there are 2 ways to do this
# ## 1. defined functions
# ## 2. lamba functions

# %%
# define a function that takes an input, squares it, adds 7, then returns the answer
def x2p7(x):
    """    this is my documentation string
    it needs to be in triple double quotes
    this function returns x^2 + 7"""
    y = x*x
    z = y+7
    return z

print('x^2 + 7 = ',x2p7(5))
print(x2p7.__doc__)
# Out:
# x^2 + 7 =  32
# this is my documentation string
# it needs to be in triple double quotes
# this function returns x^2 + 7

# %%
#if we have a documnetation string we can quickly acess through a shift tab
x2p7
# Out:
# <function __main__.x2p7(x)>

# %%
# these functions can be very complicated
def complicated_function(x,y):
    lenx = len(x)
    leny = len(y)
    z = [0]*(lenx*leny)
    counter = 0
    for i in x:
        for j in y:
            z[counter] = i*j
            counter = counter+1
    return z

output = complicated_function([1,2,3,4],[34,234,31,888])
print(output)
# Out:
# [34, 234, 31, 888, 68, 468, 62, 1776, 102, 702, 93, 2664, 136, 936, 124, 3552]

# %%
# Scope
print(lenx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Scope
# ----> 2 print(lenx)
#
# NameError: name 'lenx' is not defined

# %%
# a variable defined inside a function cannot be accessed from outside the function
# but a variable defined outside a function can be accessed from inside the function!
outside_var = 213
def a_function(x):
    return outside_var*x

print(a_function(2))
print(outside_var)
# Out:
# 426
# 213

# %%
# we can address the scope issue by declaring a variable as global
def another_function(x):
    global global_var
    global_var = 5
    return global_var*x

print(another_function(4))
print(global_var)
# Out:
# 20
# 5

# %%
# the first function we wrote (x2p7) was actually a very simple function
# we can define such simple functions 'inline' using something called a lambda function

x2p7v2 = lambda x: x*x+7
print(x2p7v2(5))
# Out:
# 32

# %%
# lambda functions can also take more than 1 input
another_lambda = lambda x,y,z: x*y + y*z + x/y
print(another_lambda(2,5,6))
# Out:
# 40.4

# %% [markdown]
# # oops theory

# %% [markdown]
# # what is object oriented programming
# ## is just a way of language definition of talking about classes and objects

# %% [markdown]
# # what is  a class
# ## a class is a user defined data type
# ### a class is a user defined data type, where we give a name to the data type
#
# ### int is the name of a data type, float is the name of a data type, list is the name of a data type
#
# ### Similarly, if I define a class called My_data_type then My_data_type is the name of a data type.
#
# ### This data type can contain many variables inside of it with each variariable possibly being of different data types, and each variable can have it's own name. At first glance a class seems a lot like a dictionary. We will soon see how it's different.
#
# #### if i define a class called my_data_type then my_data_type is going to be the  name of a new data type in the python

# %% [markdown]
# # Attributes
# ## A variable inside a class is called an attribute.

# %% [markdown]
# # Methods
# ## How is this different than a list or dictionary?
#
# ## You can also have functions inside of a class. You call a function that is inside of a class a method
#
# ## These functions can perform calculations on the attributes or on data fed to them from outside of the class.
#
# ## In the declaration of a class you can only define methods. If you want to declare an attribute this must be done inside a method.

# %% [markdown]
# # Objects
# ## An object is an instance of a particular class.
#
# ## For example, one existing data type in python is int
#
# ## If I define a variable as first_int = 6
#
# ## Then first_int is an object of the type int
#
# ## I can also define second_int = 532
#
# ## This is another instance of the type int
#
# ## These two instances of the type int have different values assigned to them!
#
# ## Similarly I can define my own type of variable as a class called My_data_type, then I can declare multiple objects of the class My_data_type, each having different names and possibly having different values assigned to their attributes and different execution of the methods. We have to name the data type (int), but we also have to name each instance of the data type (first_int, second_int).
#
# ## This will all become clear when we do an example.

# %% [markdown]
# # Initializer
# ## If you want to assign some attribute values to your object when you declare it we use an initializer in the class definition. We can also automatically run other methods from inside the initializer at the time of declaration.

# %% [markdown]
# # self
# ## self is an important concept for classes. self is python's internal reference identifier for classes. It serves 2 main purposes.
#
# ## When you add an attribute (variable) in a class you must name it self.attribute_name. Then when you declare an object of that class you access that attribute from the outside as object_name.attribute_name, or if you want to use it interally in a method you would reference it as self.attribute_name.
#
# ## When you add a method (function) to a class, you must have self as the first argument of that function. but when you call a function you don't actually input self... this is a little confusing.
